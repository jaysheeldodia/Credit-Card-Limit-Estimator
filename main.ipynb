# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv("credit.csv")
df.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %% [markdown]
# ## Check for NULL values

# %%
df.isna().any()
# Out:
# Income       False
# Limit        False
# Rating       False
# Cards        False
# Age          False
# Education    False
# Gender       False
# Student      False
# Married      False
# Ethnicity    False
# Balance      False
# dtype: bool

# %% [markdown]
# ## Columns

# %%
df.columns
# Out:
# Index(['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Gender',
#        'Student', 'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %% [markdown]
# ## Check shape of the dataframe

# %%
df.shape
# Out:
# (400, 11)

# %% [markdown]
# ## Check for max and min values of all the columns

# %% [markdown]
# ### Define the function

# %%
def unique_vals(cols):
    for col in cols:
        print(f"Unique value for {col} is", df[col].unique())

# %%
unique_vals(['Gender', 'Student', 'Married', 'Ethnicity'])
# Out:
# Unique value for Gender is ['Male' 'Female']
# Unique value for Student is ['No' 'Yes']
# Unique value for Married is ['Yes' 'No']
# Unique value for Ethnicity is ['Caucasian' 'Asian' 'African American']

# %%
def max_min_vals(cols):
    for col in cols:
        print(f"For column {col}: Min Value = {df[col].min()} and Max Value = {df[col].max()}")

# %% [markdown]
# ## Perform One Hot Encoding

# %%
X = df.drop('Limit', axis=1)
y = df.Limit

# %%
X.columns
# Out:
# Index(['Income', 'Rating', 'Cards', 'Age', 'Education', 'Gender', 'Student',
#        'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %%
X_ohe = pd.get_dummies(X, ['Gender', 'Student', 'Married', 'Ethnicity'])
X_ohe.head()
# Out:
#     Income  Rating  Cards  Age  Education  Balance  Gender_Female  \
# 0   14.891     283      2   34         11      333          False
# 1  106.025     483      3   82         15      903           True
# 2  104.593     514      4   71         11      580          False
# 3  148.924     681      3   36         11      964           True
# 4   55.882     357      2   68         16      331          False
#
#    Gender_Male  Student_No  Student_Yes  Married_No  Married_Yes  \
# 0         True        True        False       False         True
# 1        False       False         True       False         True
# 2         True        True        False        True        False
# 3        False        True        False        True        False
# 4         True        True        False       False         True
#
#    Ethnicity_African American  Ethnicity_Asian  Ethnicity_Caucasian
# 0                       False            False                 True
# 1                       False             True                False
# 2                       False             True                False
# 3                       False             True                False
# 4                       False            False                 True

# %%
X_ohe.columns
# Out:
# Index(['Income', 'Rating', 'Cards', 'Age', 'Education', 'Balance',
#        'Gender_Female', 'Gender_Male', 'Student_No', 'Student_Yes',
#        'Married_No', 'Married_Yes', 'Ethnicity_African American',
#        'Ethnicity_Asian', 'Ethnicity_Caucasian'],
#       dtype='object')

# %%
X_ohe = X_ohe.drop(['Gender_Female', 'Student_No', 'Married_No', 'Ethnicity_African American'], axis=1)
X_ohe
# Out:
#       Income  Rating  Cards  Age  Education  Balance  Gender_Male  \
# 0     14.891     283      2   34         11      333         True
# 1    106.025     483      3   82         15      903        False
# 2    104.593     514      4   71         11      580         True
# 3    148.924     681      3   36         11      964        False
# 4     55.882     357      2   68         16      331         True
# ..       ...     ...    ...  ...        ...      ...          ...
# 395   12.096     307      3   32         13      560         True
# 396   13.364     296      5   65         17      480         True
# 397   57.872     321      5   67         12      138        False
# 398   37.728     192      1   44         13        0         True
# 399   18.701     415      5   64          7      966        False
#
#      Student_Yes  Married_Yes  Ethnicity_Asian  Ethnicity_Caucasian
# 0          False         True            False                 True
# 1           True         True             True                False
# 2          False        False             True                False
# 3          False        False             True                False
# 4          False         True            False                 True
# ..           ...          ...              ...                  ...
# 395        False         True            False                 True
# 396        False        False            False                False
# 397        False         True            False                 True
# 398        False         True            False                 True
# 399        False        False             True                False
#
# [400 rows x 11 columns]

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.4, random_state=42)

# %%
# test_1 = [14.891, 283, 2, 34, 11,333, 1, 0, 1, 0, 1]
test_1 = [106.025, 483, 3, 82, 15, 903, 0, 1, 1, 0, 1]

# %% [markdown]
# ## Model Creation

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict([test_1])
# Out:
# d:\Source Code\Credit Card Limit Estimator\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6582.98472127])

# %% [markdown]
# ## Model evaluation

# %%
lr.score(X_test, y_test)
# Out:
# 0.9960666390121163

# %% [markdown]
# ## Saving the model

# %%
import joblib

# %%
filename = "LimitEstimator.pkl"
joblib.dump(lr, filename)
# Out:
# ['LimitEstimator.pkl']
